# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import csv
from csv import writer #allows us to add rows in csv file
from io import StringIO
from pandas import *
from array import *
import disney_package # import package
# %matplotlib inline

#lets first makes sure there no empty cells in our dataset 

df = pd.read_csv("/content/disney_movies.csv")
df[['mpaa_rating']] = df[['mpaa_rating']].fillna("Not Rated") #select Column mpa_rating replace all NaN with "Not Rated"
df[['genre']] = df[['genre']].fillna("No Genre") #select Column genre replace all NaN with "No Genre"
df.to_csv('noNullDisney.csv', index=False) #lets save this new dataset to a new name " noNullDisney"
df.drop
df.head()
# Out:
#                        movie_title  ... inflation_adjusted_gross
# 0  Snow White and the Seven Dwarfs  ...               5228953251
# 1                        Pinocchio  ...               2188229052
# 2                         Fantasia  ...               2187090808
# 3                Song of the South  ...               1078510579
# 4                       Cinderella  ...                920608730
#
# [5 rows x 6 columns]

# %%
#since we have certain movies that either don't have a rating or genre or both we have 4 different sets of data 
#lets first extract the data set that contain only movies that have values for all columns
df = df[df.mpaa_rating != "Not Rated"] # removes all rows that contain "Not Rated" in rating column
df = df[df.genre != "No Genre"] #removes all rows that contain "No Genre" in genre column 
df.to_csv('noEmptyDisney.csv', index=False) #Save dataset as new csv noEmptyDisney
df.head()
# Out:
#                        movie_title  ... inflation_adjusted_gross
# 0  Snow White and the Seven Dwarfs  ...               5228953251
# 1                        Pinocchio  ...               2188229052
# 2                         Fantasia  ...               2187090808
# 3                Song of the South  ...               1078510579
# 4                       Cinderella  ...                920608730
#
# [5 rows x 6 columns]

# %%
filename = open('/content/disney_movies.csv', 'r')
file = csv.DictReader(filename)
movieTitle = []
releaseDate = []
genre =[]
rating = []
totalGross = []
adjustedInflat = []

for col in file:
  movieTitle.append(col['movie_title'])
  releaseDate.append(col['release_date'])
  genre.append(col['genre'])
  rating.append(col['mpaa_rating'])
  totalGross.append(col['total_gross'])
  adjustedInflat.append(col['inflation_adjusted_gross'])

print(movieTitle)
print(releaseDate)
print(genre)
print(rating)
print(totalGross)
print(adjustedInflat)
# Out:
# ['Snow White and the Seven Dwarfs', 'Pinocchio', 'Fantasia', 'Song of the South', 'Cinderella', '20,000 Leagues Under the Sea', 'Lady and the Tramp', 'Sleeping Beauty', '101 Dalmatians', 'The Absent Minded Professor', 'Babes in Toyland', 'Bon Voyage!', 'The Sword in the Stone', 'The Jungle Book', "Blackbeard's Ghost", 'The Aristocats', 'The Boatniks', 'Bedknobs and Broomsticks', 'The Apple Dumpling Gang', 'Freaky Friday', 'The Many Adventures of Winnie the Pooh', 'The Rescuers', 'Herbie Goes to Monte Carlo', 'The Black Hole', 'Midnight Madness', 'The Last Flight of Noah’s Ark', 'The Devil and Max Devlin', 'Amy', 'The Fox and the Hound', 'Condorman', 'Night Crossing', 'Tron', 'Tex', 'Trenchcoat', 'Something Wicked This Way Comes', 'Never Cry Wolf', 'Running Brave', 'Splash', 'Country', 'Baby: Secret of the Lost Legend', 'Return to Oz', 'The Black Cauldron', 'My Science Project', 'The Journey of Natty Gann', 'One Magic Christmas', 'Down and Out in Beverly Hills', 'Off Beat', 'Ruthless 
# ...

# %%
disneyMovies = np.vstack((movieTitle, releaseDate, genre, rating, totalGross, adjustedInflat)) #using vstack() from numpy we stack long the columns
np.set_printoptions(threshold=10000, linewidth=1000)
print(disneyMovies)
# Out:
# [['Snow White and the Seven Dwarfs' 'Pinocchio' 'Fantasia' 'Song of the South' 'Cinderella' '20,000 Leagues Under the Sea' 'Lady and the Tramp' 'Sleeping Beauty' '101 Dalmatians' 'The Absent Minded Professor' 'Babes in Toyland' 'Bon Voyage!' 'The Sword in the Stone' 'The Jungle Book' "Blackbeard's Ghost" 'The Aristocats' 'The Boatniks' 'Bedknobs and Broomsticks' 'The Apple Dumpling Gang' 'Freaky Friday' 'The Many Adventures of Winnie the Pooh' 'The Rescuers' 'Herbie Goes to Monte Carlo' 'The Black Hole' 'Midnight Madness' 'The Last Flight of Noah’s Ark' 'The Devil and Max Devlin' 'Amy' 'The Fox and the Hound' 'Condorman' 'Night Crossing' 'Tron' 'Tex' 'Trenchcoat' 'Something Wicked This Way Comes' 'Never Cry Wolf' 'Running Brave' 'Splash' 'Country' 'Baby: Secret of the Lost Legend' 'Return to Oz' 'The Black Cauldron' 'My Science Project' 'The Journey of Natty Gann' 'One Magic Christmas' 'Down and Out in Beverly Hills' 'Off Beat' 'Ruthless People' 'The Great Mouse Detective'
# ...

# %%
a = [row[342] for row in disneyMovies] #captures index row from 2D array using for loop, number indicate row number
b = [row[235] for row in disneyMovies]
c = [row[321] for row in disneyMovies]
d = [row[179] for row in disneyMovies]
e = [row[275] for row in disneyMovies]
f = [row[342] for row in disneyMovies]
a1 = " , ".join(a) #this allows us to convert the list into a string seperated by commas 
b1 = " , ".join(b)
c1 = " , ".join(c)
d1 = " , ".join(d)
e1 = " , ".join(e)
f1 = " , ".join(f)
dis = open("data.txt", "w") 
dis.writelines(a1)
dis.write("\n") #adds next line 
dis.writelines(b1)
dis.write("\n")
dis.writelines(c1)
dis.write("\n")
dis.writelines(d1)
dis.write("\n")
dis.writelines(e1)
dis.write("\n")
dis.writelines(f1)
dis.close()

# %%
list1 = np.genfromtxt("data.txt", dtype=None, encoding=None, delimiter=",") #
list2 = np.genfromtxt("data2.txt", dtype=None, encoding=None, delimiter=",")

with open('testbook1.csv', 'a' ) as f_object: #adds rows to csv file 
  writer_object = writer(f_object)
  writer_object.writerows(list1) #adds list1 to the csv file that is called
  f_object.close()


with open('testbook2.csv', 'a' ) as f_object2: #adds rows to csv file 
  writer_object = writer(f_object2)
  writer_object.writerows(list2) #adds list1 to the csv file that is called
  f_object2.close()

ndf = pd.read_csv("testbook1.csv")
ndf2 = pd.read_csv("testbook2.csv")

frames=[ndf, ndf2]
result = pd.concat(frames)
display(result)
# Out:
#                        movie_title  ...  inflation_adjusted_gross\t
# 0                   Just Visiting   ...                     7114869
# 1       James and the Giant Peach   ...                    55159783
# 2            Fantasia 2000 (IMAX)   ...                    94852354
# 3                   The Lion King   ...                   761640898
# 4   An American Werewolf in Paris   ...                    48546161
# 5                   Just Visiting   ...                     7114869
# 6                   Just Visiting   ...                     7114869
# 7       James and the Giant Peach   ...                    55159783
# 8            Fantasia 2000 (IMAX)   ...                    94852354
# 9                   The Lion King   ...                   761640898
# 10  An American Werewolf in Paris   ...                    48546161
# 11                  Just Visiting   ...                     7114869
# 0                            Test1  ...                      200000
# ...

# %%
result.drop_duplicates(subset=['movie_title'])
# Out:
#                       movie_title  ...  inflation_adjusted_gross\t
# 0                  Just Visiting   ...                     7114869
# 1      James and the Giant Peach   ...                    55159783
# 2           Fantasia 2000 (IMAX)   ...                    94852354
# 3                  The Lion King   ...                   761640898
# 4  An American Werewolf in Paris   ...                    48546161
# 0                           Test1  ...                      200000
# 1                           Test2  ...                      300000
# 2                           Test3  ...                      500000
# 3                           Test4  ...                      700000
# 4                           Test5  ...                      900000
# 5                           Test6  ...                      120000
# 6                     movie_title  ...  inflation_adjusted_gross\t
#
# [12 rows x 6 columns]

# %%
adv = df.loc[df['genre'] == 'Adventure']
adv.sort_values(by=['inflation_adjusted_gross'], ascending=False)
# Out:
#                               movie_title  ... inflation_adjusted_gross
# 1                               Pinocchio  ...               2188229052
# 3                       Song of the South  ...               1078510579
# 564  Star Wars Ep. VII: The Force Awakens  ...                936662225
# 179                         The Lion King  ...                761640898
# 441  Pirates of the Caribbean: Dead Man’…  ...                544817142
# ..                                    ...  ...                      ...
# 554                         Strange Magic  ...                 12429583
# 394                  Young Black Stallion  ...                  9254344
# 420                  Hauru no ugoku shiro  ...                  6194870
# 502      Gedo Senki (Tales from Earthsea)  ...                    51988
# 511                              Zokkomon  ...                     2984
#
# [119 rows x 6 columns]
